# %%
import json

# load json file
def load_json(file_path: str) -> dict:
    with open(file_path, 'r') as f:
        data = json.load(f)
    return data

data = load_json("/mnt/c/Users/hoxia/Documents/NLDeeznuts/gpt2-image-captioning/data/data/coco/annotations/captions_train2014.json")

# %%
data.keys()
# Out:
# dict_keys(['info', 'images', 'licenses', 'annotations'])

# %%
data['annotations'][0]
# Out:
# {'image_id': 318556,
#  'id': 48,
#  'caption': 'A very clean and well decorated empty bathroom'}

# %%
import torch

# load the pt file
data_pt = torch.load("/mnt/c/Users/hoxia/Documents/NLDeeznuts/gpt2-image-captioning/data/data/coco/embeddings/train_val_clip_embeddings.pt")

# %%
# analyze the data_pt structure
data_pt.keys()
# Out:
# dict_keys(['filenames', 'embeddings'])

# %%
data_pt['filenames']
# Out:
# ['COCO_train2014_000000263229.jpg',
#  'COCO_train2014_000000381595.jpg',
#  'COCO_train2014_000000147733.jpg',
#  'COCO_train2014_000000559395.jpg',
#  'COCO_train2014_000000374072.jpg',
#  'COCO_train2014_000000233539.jpg',
#  'COCO_train2014_000000213863.jpg',
#  'COCO_train2014_000000471409.jpg',
#  'COCO_train2014_000000487632.jpg',
#  'COCO_train2014_000000242092.jpg',
#  'COCO_train2014_000000203982.jpg',
#  'COCO_train2014_000000540384.jpg',
#  'COCO_train2014_000000186883.jpg',
#  'COCO_train2014_000000447520.jpg',
#  'COCO_train2014_000000316443.jpg',
#  'COCO_train2014_000000087507.jpg',
#  'COCO_train2014_000000069256.jpg',
#  'COCO_train2014_000000259616.jpg',
#  'COCO_train2014_000000494409.jpg',
#  'COCO_train2014_000000351298.jpg',
#  'COCO_train2014_000000464415.jpg',
#  'COCO_train2014_000000044954.jpg',
#  'COCO_train2014_000000079696.jpg',
#  'COCO_train2014_000000096573.jpg',
#  'COCO_train2014_000000098257.jpg',
#  'COCO_train2014_000000517936.jpg',
#  'COCO_train2014_000000368731.jpg',
#  'COCO_train2014_000000462131.jpg',
#  'COCO_train2014_000000034439.jpg',
#  'COCO_train2014_000000093786.jpg',
#  'COCO_train2014_000000211807.jpg',
#  'COCO_train2014_000000437391.jpg',
#  'COCO_train2014_000000130908.jpg',
#  'COCO_train2014_000000314093.jpg',
#  'COCO_train2014_000000474597.jpg',
#  'COCO_train2014_000000006733.jpg',
#  'COCO_train2014_000000425773.jpg',
#  'COCO_train2014_000000296432.jpg',
#  'COCO_train2014_000000014819.jpg',
#  'COCO_train2014_000000107565.jpg',
#  'COCO_train2014_000000008058.jpg',
#  'COCO_train2014_000000264598.jpg',
#  'COCO_train2014_000000352288.jpg',
#  'COCO_train2014_000000569838.jpg',
#  'COCO_train2014_000000162390.jpg',
#  'COCO_train2014_000000218399.jpg',
#  'COCO_train2014_000000469648.jpg',
#  'COCO_train2014_000000533356.jpg',
#  'COCO_train2014_000000175991.jpg',
#  'COCO_train2014_000000071159.jpg',
#  'COCO_train2014_000000293070.jpg',
#  'COCO_train2014_000000399227.jpg',
#  'COCO_train2014_000000163985.jpg',
#  'COCO_train2014_000000030910.jpg',
#  'COCO_train2014_000000131884.jpg',
#  'COCO_train2014_000000366153.jpg',
#  'COCO_train2014_000000176086.jpg',
#  'COCO_train2014_000000205814.jpg',
#  'COCO_train2014_000000265980.jpg',
#  'COCO_train2014_000000066266.jpg',
#  'COCO_train2014_000000186255.jpg',
#  'COCO_train2014_000000335216.jpg',
#  'COCO_train2014_000000163263.jpg',
#  'COCO_train2014_000000365013.jpg',
#  'COCO_train2014_000000055119.jpg',
#  'COCO_train2014_000000518410.jpg',
#  'COCO_train2014_000000107097.jpg',
#  'COCO_train2014_000000445965.jpg',
#  'COCO_train2014_000000373414.jpg',
#  'COCO_train2014_000000126743.jpg',
#  'COCO_train2014_000000581073.jpg',
#  'COCO_train2014_000000053091.jpg',
#  'COCO_train2014_000000511179.jpg',
#  'COCO_train2014_000000157920.jpg',
#  'COCO_train2014_000000569989.jpg',
#  'COCO_train2014_000000141441.jpg',
#  'COCO_train2014_000000129331.jpg',
#  'COCO_train2014_000000121211.jpg',
#  'COCO_train2014_000000349393.jpg',
#  'COCO_train2014_000000569511.jpg',
#  'COCO_train2014_000000246869.jpg',
#  'COCO_train2014_000000204014.jpg',
#  'COCO_train2014_000000187268.jpg',
#  'COCO_train2014_000000246099.jpg',
#  'COCO_train2014_000000509415.jpg',
#  'COCO_train2014_000000133151.jpg',
#  'COCO_train2014_000000305409.jpg',
#  'COCO_train2014_000000068367.jpg',
#  'COCO_train2014_000000292181.jpg',
#  'COCO_train2014_000000034454.jpg',
#  'COCO_train2014_000000068817.jpg',
#  'COCO_train2014_000000487735.jpg',
#  'COCO_train2014_000000133247.jpg',
#  'COCO_train2014_000000540326.jpg',
#  'COCO_train2014_000000412468.jpg',
#  'COCO_train2014_000000561622.jpg',
#  'COCO_train2014_000000418091.jpg',
#  'COCO_train2014_000000415354.jpg',
#  'COCO_train2014_000000509839.jpg',
#  'COCO_train2014_000000552565.jpg',
#  'COCO_train2014_000000522575.jpg',
#  'COCO_train2014_000000251191.jpg',
#  'COCO_train2014_000000247086.jpg',
#  'COCO_train2014_000000519356.jpg',
#  'COCO_train2014_000000474670.jpg',
#  'COCO_train2014_000000179480.jpg',
#  'COCO_train2014_000000061834.jpg',
#  'COCO_train2014_000000287934.jpg',
#  'COCO_train2014_000000433296.jpg',
#  'COCO_train2014_000000028231.jpg',
#  'COCO_train2014_000000186108.jpg',
#  'COCO_train2014_000000249791.jpg',
#  'COCO_train2014_000000168475.jpg',
#  'COCO_train2014_000000492386.jpg',
#  'COCO_train2014_000000246563.jpg',
#  'COCO_train2014_000000276931.jpg',
#  'COCO_train2014_000000011801.jpg',
#  'COCO_train2014_000000474963.jpg',
#  'COCO_train2014_000000135592.jpg',
#  'COCO_train2014_000000284259.jpg',
#  'COCO_train2014_000000346313.jpg',
#  'COCO_train2014_000000188757.jpg',
#  'COCO_train2014_000000269152.jpg',
#  'COCO_train2014_000000285360.jpg',
#  'COCO_train2014_000000223755.jpg',
#  'COCO_train2014_000000431812.jpg',
#  'COCO_train2014_000000383212.jpg',
#  'COCO_train2014_000000229236.jpg',
#  'COCO_train2014_000000185474.jpg',
#  'COCO_train2014_000000050636.jpg',
#  'COCO_train2014_000000037011.jpg',
#  'COCO_train2014_000000313481.jpg',
#  'COCO_train2014_000000135041.jpg',
#  'COCO_train2014_000000286702.jpg',
#  'COCO_train2014_000000470762.jpg',
#  'COCO_train2014_000000554310.jpg',
#  'COCO_train2014_000000178504.jpg',
#  'COCO_train2014_000000478683.jpg',
#  'COCO_train2014_000000103502.jpg',
#  'COCO_train2014_000000434986.jpg',
#  'COCO_train2014_000000530823.jpg',
#  'COCO_train2014_000000189491.jpg',
#  'COCO_train2014_000000186109.jpg',
#  'COCO_train2014_000000389048.jpg',
#  'COCO_train2014_000000039580.jpg',
#  'COCO_train2014_000000167956.jpg',
#  'COCO_train2014_000000495610.jpg',
#  'COCO_train2014_000000454813.jpg',
#  'COCO_train2014_000000178666.jpg',
#  'COCO_train2014_000000527083.jpg',
#  'COCO_train2014_000000209353.jpg',
#  'COCO_train2014_000000416948.jpg',
#  'COCO_train2014_000000316269.jpg',
#  'COCO_train2014_000000166864.jpg',
#  'COCO_train2014_000000325863.jpg',
#  'COCO_train2014_000000407770.jpg',
#  'COCO_train2014_000000096244.jpg',
#  'COCO_train2014_000000408680.jpg',
#  'COCO_train2014_000000488584.jpg',
#  'COCO_train2014_000000244206.jpg',
#  'COCO_train2014_000000486835.jpg',
#  'COCO_train2014_000000230655.jpg',
#  'COCO_train2014_000000471762.jpg',
#  'COCO_train2014_000000422261.jpg',
#  'COCO_train2014_000000426857.jpg',
#  'COCO_train2014_000000145502.jpg',
#  'COCO_train2014_000000188922.jpg',
#  'COCO_train2014_000000399774.jpg',
#  'COCO_train2014_000000515704.jpg',
#  'COCO_train2014_000000427958.jpg',
#  'COCO_train2014_000000521712.jpg',
#  'COCO_train2014_000000245206.jpg',
#  'COCO_train2014_000000505082.jpg',
#  'COCO_train2014_000000456416.jpg',
#  'COCO_train2014_000000035265.jpg',
#  'COCO_train2014_000000532115.jpg',
#  'COCO_train2014_000000102445.jpg',
#  'COCO_train2014_000000254948.jpg',
#  'COCO_train2014_000000530086.jpg',
#  'COCO_train2014_000000436246.jpg',
#  'COCO_train2014_000000051110.jpg',
#  'COCO_train2014_000000293371.jpg',
#  'COCO_train2014_000000325008.jpg',
#  'COCO_train2014_000000298112.jpg',
#  'COCO_train2014_000000160549.jpg',
#  'COCO_train2014_000000054304.jpg',
#  'COCO_train2014_000000349585.jpg',
#  'COCO_train2014_000000207980.jpg',
#  'COCO_train2014_000000011990.jpg',
#  'COCO_train2014_000000099902.jpg',
#  'COCO_train2014_000000523318.jpg',
#  'COCO_train2014_000000364135.jpg',
#  'COCO_train2014_000000263420.jpg',
#  'COCO_train2014_000000561821.jpg',
#  'COCO_train2014_000000575267.jpg',
#  'COCO_train2014_000000045204.jpg',
#  'COCO_train2014_000000051027.jpg',
#  'COCO_train2014_000000019695.jpg',
#  'COCO_train2014_000000323162.jpg',
#  'COCO_train2014_000000415889.jpg',
#  'COCO_train2014_000000105222.jpg',
#  'COCO_train2014_000000420446.jpg',
#  'COCO_train2014_000000378710.jpg',
#  'COCO_train2014_000000504833.jpg',
#  'COCO_train2014_000000322755.jpg',
#  'COCO_train2014_000000269229.jpg',
#  'COCO_train2014_000000029432.jpg',
#  'COCO_train2014_000000080826.jpg',
#  'COCO_train2014_000000378087.jpg',
#  'COCO_train2014_000000179390.jpg',
#  'COCO_train2014_000000207992.jpg',
#  'COCO_train2014_000000560571.jpg',
#  'COCO_train2014_000000287886.jpg',
#  'COCO_train2014_000000554323.jpg',
#  'COCO_train2014_000000465784.jpg',
#  'COCO_train2014_000000261729.jpg',
#  'COCO_train2014_000000406657.jpg',
#  'COCO_train2014_000000048759.jpg',
#  'COCO_train2014_000000523166.jpg',
#  'COCO_train2014_000000516587.jpg',
#  'COCO_train2014_000000443790.jpg',
#  'COCO_train2014_000000448503.jpg',
#  'COCO_train2014_000000116677.jpg',
#  'COCO_train2014_000000288453.jpg',
#  'COCO_train2014_000000040569.jpg',
#  'COCO_train2014_000000510004.jpg',
#  'COCO_train2014_000000179418.jpg',
#  'COCO_train2014_000000509901.jpg',
#  'COCO_train2014_000000267988.jpg',
#  'COCO_train2014_000000084803.jpg',
#  'COCO_train2014_000000322790.jpg',
#  'COCO_train2014_000000296770.jpg',
#  'COCO_train2014_000000360110.jpg',
#  'COCO_train2014_000000146401.jpg',
#  'COCO_train2014_000000374956.jpg',
#  'COCO_train2014_000000058102.jpg',
#  'COCO_train2014_000000376590.jpg',
#  'COCO_train2014_000000559053.jpg',
#  'COCO_train2014_000000386272.jpg',
#  'COCO_train2014_000000137589.jpg',
#  'COCO_train2014_000000253728.jpg',
#  'COCO_train2014_000000141460.jpg',
#  'COCO_train2014_000000355991.jpg',
#  'COCO_train2014_000000553505.jpg',
#  'COCO_train2014_000000143499.jpg',
#  'COCO_train2014_000000038198.jpg',
#  'COCO_train2014_000000425629.jpg',
#  'COCO_train2014_000000177404.jpg',
#  'COCO_train2014_000000535445.jpg',
#  'COCO_train2014_000000256546.jpg',
#  'COCO_train2014_000000265826.jpg',
#  'COCO_train2014_000000352508.jpg',
#  'COCO_train2014_000000005010.jpg',
#  'COCO_train2014_000000447689.jpg',
#  'COCO_train2014_000000380128.jpg',
#  'COCO_train2014_000000026719.jpg',
#  'COCO_train2014_000000497558.jpg',
#  'COCO_train2014_000000439322.jpg',
#  'COCO_train2014_000000391807.jpg',
#  'COCO_train2014_000000537246.jpg',
#  'COCO_train2014_000000490570.jpg',
#  'COCO_train2014_000000458625.jpg',
#  'COCO_train2014_000000259093.jpg',
#  'COCO_train2014_000000390608.jpg',
#  'COCO_train2014_000000511301.jpg',
#  'COCO_train2014_000000279197.jpg',
#  'COCO_train2014_000000254183.jpg',
#  'COCO_train2014_000000392083.jpg',
#  'COCO_train2014_000000458483.jpg',
#  'COCO_train2014_000000330133.jpg',
#  'COCO_train2014_000000154359.jpg',
#  'COCO_train2014_000000066124.jpg',
#  'COCO_train2014_000000482128.jpg',
#  'COCO_train2014_000000289352.jpg',
#  'COCO_train2014_000000229794.jpg',
#  'COCO_train2014_000000092346.jpg',
#  'COCO_train2014_000000147890.jpg',
#  'COCO_train2014_000000469531.jpg',
#  'COCO_train2014_000000105531.jpg',
#  'COCO_train2014_000000234819.jpg',
#  'COCO_train2014_000000277088.jpg',
#  'COCO_train2014_000000011288.jpg',
#  'COCO_train2014_000000068953.jpg',
#  'COCO_train2014_000000211557.jpg',
#  'COCO_train2014_000000024132.jpg',
#  'COCO_train2014_000000491850.jpg',
#  'COCO_train2014_000000491241.jpg',
#  'COCO_train2014_000000294909.jpg',
#  'COCO_train2014_000000409652.jpg',
#  'COCO_train2014_000000071989.jpg',
#  'COCO_train2014_000000433170.jpg',
#  'COCO_train2014_000000012986.jpg',
#  'COCO_train2014_000000221420.jpg',
#  'COCO_train2014_000000161262.jpg',
#  'COCO_train2014_000000080123.jpg',
#  'COCO_train2014_000000303935.jpg',
#  'COCO_train2014_000000451825.jpg',
#  'COCO_train2014_000000060117.jpg',
#  'COCO_train2014_000000384617.jpg',
#  'COCO_train2014_000000174228.jpg',
#  'COCO_train2014_000000329191.jpg',
#  'COCO_train2014_000000153421.jpg',
#  'COCO_train2014_000000302713.jpg',
#  'COCO_train2014_000000021685.jpg',
#  'COCO_train2014_000000412167.jpg',
#  'COCO_train2014_000000282987.jpg',
#  'COCO_train2014_000000050404.jpg',
#  'COCO_train2014_000000158686.jpg',
#  'COCO_train2014_000000424665.jpg',
#  'COCO_train2014_000000454969.jpg',
#  'COCO_train2014_000000197296.jpg',
#  'COCO_train2014_000000478035.jpg',
#  'COCO_train2014_000000371510.jpg',
#  'COCO_train2014_000000319952.jpg',
#  'COCO_train2014_000000468318.jpg',
#  'COCO_train2014_000000407905.jpg',
#  'COCO_train2014_000000489414.jpg',
#  'COCO_train2014_000000191031.jpg',
#  'COCO_train2014_000000466863.jpg',
#  'COCO_train2014_000000476950.jpg',
#  'COCO_train2014_000000444348.jpg',
#  'COCO_train2014_000000179164.jpg',
#  'COCO_train2014_000000548390.jpg',
#  'COCO_train2014_000000455350.jpg',
#  'COCO_train2014_000000528117.jpg',
#  'COCO_train2014_000000249891.jpg',
#  'COCO_train2014_000000201018.jpg',
#  'COCO_train2014_000000423355.jpg',
#  'COCO_train2014_000000469026.jpg',
#  'COCO_train2014_000000079323.jpg',
#  'COCO_train2014_000000472620.jpg',
#  'COCO_train2014_000000277448.jpg',
#  'COCO_train2014_000000447993.jpg',
#  'COCO_train2014_000000409433.jpg',
#  'COCO_train2014_000000192652.jpg',
#  'COCO_train2014_000000081683.jpg',
#  'COCO_train2014_000000099718.jpg',
#  'COCO_train2014_000000080927.jpg',
#  'COCO_train2014_000000026367.jpg',
#  'COCO_train2014_000000217974.jpg',
#  'COCO_train2014_000000064520.jpg',
#  'COCO_train2014_000000181997.jpg',
#  'COCO_train2014_000000445590.jpg',
#  'COCO_train2014_000000291466.jpg',
#  'COCO_train2014_000000523754.jpg',
#  'COCO_train2014_000000316281.jpg',
#  'COCO_train2014_000000033077.jpg',
#  'COCO_train2014_000000530729.jpg',
#  'COCO_train2014_000000415131.jpg',
#  'COCO_train2014_000000212584.jpg',
#  'COCO_train2014_000000181367.jpg',
#  'COCO_train2014_000000524286.jpg',
#  'COCO_train2014_000000302932.jpg',
#  'COCO_train2014_000000232254.jpg',
#  'COCO_train2014_000000549622.jpg',
#  'COCO_train2014_000000317186.jpg',
#  'COCO_train2014_000000578734.jpg',
#  'COCO_train2014_000000205757.jpg',
#  'COCO_train2014_000000050846.jpg',
#  'COCO_train2014_000000283196.jpg',
#  'COCO_train2014_000000457344.jpg',
#  'COCO_train2014_000000443673.jpg',
#  'COCO_train2014_000000459557.jpg',
#  'COCO_train2014_000000100588.jpg',
#  'COCO_train2014_000000067057.jpg',
#  'COCO_train2014_000000257773.jpg',
#  'COCO_train2014_000000241675.jpg',
#  'COCO_train2014_000000047737.jpg',
#  'COCO_train2014_000000372709.jpg',
#  'COCO_train2014_000000055465.jpg',
#  'COCO_train2014_000000115328.jpg',
#  'COCO_train2014_000000159634.jpg',
#  'COCO_train2014_000000056032.jpg',
#  'COCO_train2014_000000345225.jpg',
#  'COCO_train2014_000000131915.jpg',
#  'COCO_train2014_000000433145.jpg',
#  'COCO_train2014_000000349138.jpg',
#  'COCO_train2014_000000219859.jpg',
#  'COCO_train2014_000000099476.jpg',
#  'COCO_train2014_000000529795.jpg',
#  'COCO_train2014_000000485080.jpg',
#  'COCO_train2014_000000162558.jpg',
#  'COCO_train2014_000000087876.jpg',
#  'COCO_train2014_000000170962.jpg',
#  'COCO_train2014_000000173620.jpg',
#  'COCO_train2014_000000303257.jpg',
#  'COCO_train2014_000000096365.jpg',
#  'COCO_train2014_000000373415.jpg',
#  'COCO_train2014_000000472065.jpg',
#  'COCO_train2014_000000560047.jpg',
#  'COCO_train2014_000000412371.jpg',
#  'COCO_train2014_000000008245.jpg',
#  'COCO_train2014_000000569774.jpg',
#  'COCO_train2014_000000048571.jpg',
#  'COCO_train2014_000000191570.jpg',
#  'COCO_train2014_000000182507.jpg',
#  'COCO_train2014_000000304067.jpg',
#  'COCO_train2014_000000319315.jpg',
#  'COCO_train2014_000000378628.jpg',
#  'COCO_train2014_000000133384.jpg',
#  'COCO_train2014_000000301110.jpg',
#  'COCO_train2014_000000380329.jpg',
#  'COCO_train2014_000000244132.jpg',
#  'COCO_train2014_000000071429.jpg',
#  'COCO_train2014_000000378832.jpg',
#  'COCO_train2014_000000212083.jpg',
#  'COCO_train2014_000000088330.jpg',
#  'COCO_train2014_000000102315.jpg',
#  'COCO_train2014_000000277141.jpg',
#  'COCO_train2014_000000504170.jpg',
#  'COCO_train2014_000000337930.jpg',
#  'COCO_train2014_000000207647.jpg',
#  'COCO_train2014_000000434039.jpg',
#  'COCO_train2014_000000341413.jpg',
#  'COCO_train2014_000000152781.jpg',
#  'COCO_train2014_000000027252.jpg',
#  'COCO_train2014_000000343922.jpg',
#  'COCO_train2014_000000074722.jpg',
#  'COCO_train2014_000000512806.jpg',
#  'COCO_train2014_000000034828.jpg',
#  'COCO_train2014_000000072495.jpg',
#  'COCO_train2014_000000154478.jpg',
#  'COCO_train2014_000000335451.jpg',
#  'COCO_train2014_000000109182.jpg',
#  'COCO_train2014_000000556089.jpg',
#  'COCO_train2014_000000443296.jpg',
#  'COCO_train2014_000000374666.jpg',
#  'COCO_train2014_000000336897.jpg',
#  'COCO_train2014_000000566587.jpg',
#  'COCO_train2014_000000539016.jpg',
#  'COCO_train2014_000000271183.jpg',
#  'COCO_train2014_000000474174.jpg',
#  'COCO_train2014_000000513805.jpg',
#  'COCO_train2014_000000274402.jpg',
#  'COCO_train2014_000000229474.jpg',
#  'COCO_train2014_000000349083.jpg',
#  'COCO_train2014_000000345864.jpg',
#  'COCO_train2014_000000152461.jpg',
#  'COCO_train2014_000000023199.jpg',
#  'COCO_train2014_000000220289.jpg',
#  'COCO_train2014_000000177314.jpg',
#  'COCO_train2014_000000393896.jpg',
#  'COCO_train2014_000000365620.jpg',
#  'COCO_train2014_000000433472.jpg',
#  'COCO_train2014_000000391406.jpg',
#  'COCO_train2014_000000072592.jpg',
#  'COCO_train2014_000000205547.jpg',
#  'COCO_train2014_000000268114.jpg',
#  'COCO_train2014_000000082301.jpg',
#  'COCO_train2014_000000350310.jpg',
#  'COCO_train2014_000000330712.jpg',
#  'COCO_train2014_000000566785.jpg',
#  'COCO_train2014_000000438795.jpg',
#  'COCO_train2014_000000110710.jpg',
#  'COCO_train2014_000000521865.jpg',
#  'COCO_train2014_000000514955.jpg',
#  'COCO_train2014_000000239581.jpg',
#  'COCO_train2014_000000176551.jpg',
#  'COCO_train2014_000000401812.jpg',
#  'COCO_train2014_000000359805.jpg',
#  'COCO_train2014_000000497199.jpg',
#  'COCO_train2014_000000348146.jpg',
#  'COCO_train2014_000000252787.jpg',
#  'COCO_train2014_000000568393.jpg',
#  'COCO_train2014_000000046809.jpg',
#  'COCO_train2014_000000070710.jpg',
#  'COCO_train2014_000000382662.jpg',
#  'COCO_train2014_000000201168.jpg',
#  'COCO_train2014_000000375743.jpg',
#  'COCO_train2014_000000556851.jpg',
#  'COCO_train2014_000000501864.jpg',
#  'COCO_train2014_000000058464.jpg',
#  'COCO_train2014_000000414975.jpg',
#  'COCO_train2014_000000441659.jpg',
#  'COCO_train2014_000000057334.jpg',
#  'COCO_train2014_000000304143.jpg',
#  'COCO_train2014_000000356097.jpg',
#  'COCO_train2014_000000223139.jpg',
#  'COCO_train2014_000000370157.jpg',
#  'COCO_train2014_000000200618.jpg',
#  'COCO_train2014_000000403325.jpg',
#  'COCO_train2014_000000484832.jpg',
#  'COCO_train2014_000000424489.jpg',
#  'COCO_train2014_000000139634.jpg',
#  'COCO_train2014_000000201644.jpg',
#  'COCO_train2014_000000034539.jpg',
#  'COCO_train2014_000000220568.jpg',
#  'COCO_train2014_000000033773.jpg',
#  'COCO_train2014_000000406579.jpg',
#  'COCO_train2014_000000308825.jpg',
#  'COCO_train2014_000000131084.jpg',
#  'COCO_train2014_000000274248.jpg',
#  'COCO_train2014_000000544728.jpg',
#  'COCO_train2014_000000300307.jpg',
#  'COCO_train2014_000000354145.jpg',
#  'COCO_train2014_000000300424.jpg',
#  'COCO_train2014_000000085933.jpg',
#  'COCO_train2014_000000196178.jpg',
#  'COCO_train2014_000000424429.jpg',
#  'COCO_train2014_000000094199.jpg',
#  'COCO_train2014_000000236698.jpg',
#  'COCO_train2014_000000369304.jpg',
#  'COCO_train2014_000000559163.jpg',
#  'COCO_train2014_000000266029.jpg',
#  'COCO_train2014_000000025801.jpg',
#  'COCO_train2014_000000488011.jpg',
#  'COCO_train2014_000000113594.jpg',
#  'COCO_train2014_000000501293.jpg',
#  'COCO_train2014_000000116126.jpg',
#  'COCO_train2014_000000572243.jpg',
#  'COCO_train2014_000000078650.jpg',
#  'COCO_train2014_000000207094.jpg',
#  'COCO_train2014_000000128102.jpg',
#  'COCO_train2014_000000495305.jpg',
#  'COCO_train2014_000000152689.jpg',
#  'COCO_train2014_000000395500.jpg',
#  'COCO_train2014_000000399154.jpg',
#  'COCO_train2014_000000226151.jpg',
#  'COCO_train2014_000000307966.jpg',
#  'COCO_train2014_000000474256.jpg',
#  'COCO_train2014_000000501307.jpg',
#  'COCO_train2014_000000456275.jpg',
#  'COCO_train2014_000000040272.jpg',
#  'COCO_train2014_000000051512.jpg',
#  'COCO_train2014_000000461632.jpg',
#  'COCO_train2014_000000253615.jpg',
#  'COCO_train2014_000000362643.jpg',
#  'COCO_train2014_000000250474.jpg',
#  'COCO_train2014_000000454912.jpg',
#  'COCO_train2014_000000408730.jpg',
#  'COCO_train2014_000000297919.jpg',
#  'COCO_train2014_000000186671.jpg',
#  'COCO_train2014_000000346391.jpg',
#  'COCO_train2014_000000045593.jpg',
#  'COCO_train2014_000000151236.jpg',
#  'COCO_train2014_000000523921.jpg',
#  'COCO_train2014_000000314065.jpg',
#  'COCO_train2014_000000361475.jpg',
#  'COCO_train2014_000000470057.jpg',
#  'COCO_train2014_000000153817.jpg',
#  'COCO_train2014_000000521199.jpg',
#  'COCO_train2014_000000442727.jpg',
#  'COCO_train2014_000000028251.jpg',
#  'COCO_train2014_000000188532.jpg',
#  'COCO_train2014_000000463953.jpg',
#  'COCO_train2014_000000343200.jpg',
#  'COCO_train2014_000000063299.jpg',
#  'COCO_train2014_000000142637.jpg',
#  'COCO_train2014_000000447196.jpg',
#  'COCO_train2014_000000309948.jpg',
#  'COCO_train2014_000000529490.jpg',
#  'COCO_train2014_000000170930.jpg',
#  'COCO_train2014_000000488857.jpg',
#  'COCO_train2014_000000487471.jpg',
#  'COCO_train2014_000000052634.jpg',
#  'COCO_train2014_000000361850.jpg',
#  'COCO_train2014_000000336511.jpg',
#  'COCO_train2014_000000405055.jpg',
#  'COCO_train2014_000000025759.jpg',
#  'COCO_train2014_000000378632.jpg',
#  'COCO_train2014_000000222506.jpg',
#  'COCO_train2014_000000385666.jpg',
#  'COCO_train2014_000000058407.jpg',
#  'COCO_train2014_000000054163.jpg',
#  'COCO_train2014_000000339295.jpg',
#  'COCO_train2014_000000157539.jpg',
#  'COCO_train2014_000000333626.jpg',
#  'COCO_train2014_000000437785.jpg',
#  'COCO_train2014_000000356064.jpg',
#  'COCO_train2014_000000233290.jpg',
#  'COCO_train2014_000000484186.jpg',
#  'COCO_train2014_000000507936.jpg',
#  'COCO_train2014_000000451415.jpg',
#  'COCO_train2014_000000562901.jpg',
#  'COCO_train2014_000000533715.jpg',
#  'COCO_train2014_000000531366.jpg',
#  'COCO_train2014_000000310348.jpg',
#  'COCO_train2014_000000476553.jpg',
#  'COCO_train2014_000000562745.jpg',
#  'COCO_train2014_000000471718.jpg',
#  'COCO_train2014_000000173089.jpg',
#  'COCO_train2014_000000122539.jpg',
#  'COCO_train2014_000000011968.jpg',
#  'COCO_train2014_000000397233.jpg',
#  'COCO_train2014_000000029956.jpg',
#  'COCO_train2014_000000051493.jpg',
#  'COCO_train2014_000000503385.jpg',
#  'COCO_train2014_000000509870.jpg',
#  'COCO_train2014_000000397254.jpg',
#  'COCO_train2014_000000541787.jpg',
#  'COCO_train2014_000000110473.jpg',
#  'COCO_train2014_000000578276.jpg',
#  'COCO_train2014_000000148540.jpg',
#  'COCO_train2014_000000462037.jpg',
#  'COCO_train2014_000000254850.jpg',
#  'COCO_train2014_000000137045.jpg',
#  'COCO_train2014_000000182444.jpg',
#  'COCO_train2014_000000467604.jpg',
#  'COCO_train2014_000000567989.jpg',
#  'COCO_train2014_000000040685.jpg',
#  'COCO_train2014_000000396977.jpg',
#  'COCO_train2014_000000574051.jpg',
#  'COCO_train2014_000000207779.jpg',
#  'COCO_train2014_000000214379.jpg',
#  'COCO_train2014_000000308257.jpg',
#  'COCO_train2014_000000399183.jpg',
#  'COCO_train2014_000000318223.jpg',
#  'COCO_train2014_000000509948.jpg',
#  'COCO_train2014_000000233039.jpg',
#  'COCO_train2014_000000441361.jpg',
#  'COCO_train2014_000000018505.jpg',
#  'COCO_train2014_000000026035.jpg',
#  'COCO_train2014_000000580434.jpg',
#  'COCO_train2014_000000027974.jpg',
#  'COCO_train2014_000000195203.jpg',
#  'COCO_train2014_000000428379.jpg',
#  'COCO_train2014_000000489514.jpg',
#  'COCO_train2014_000000325989.jpg',
#  'COCO_train2014_000000377666.jpg',
#  'COCO_train2014_000000148129.jpg',
#  'COCO_train2014_000000185452.jpg',
#  'COCO_train2014_000000298835.jpg',
#  'COCO_train2014_000000270722.jpg',
#  'COCO_train2014_000000185819.jpg',
#  'COCO_train2014_000000011426.jpg',
#  'COCO_train2014_000000454359.jpg',
#  'COCO_train2014_000000144242.jpg',
#  'COCO_train2014_000000279060.jpg',
#  'COCO_train2014_000000103722.jpg',
#  'COCO_train2014_000000519993.jpg',
#  'COCO_train2014_000000371794.jpg',
#  'COCO_train2014_000000003935.jpg',
#  'COCO_train2014_000000345238.jpg',
#  'COCO_train2014_000000237825.jpg',
#  'COCO_train2014_000000384874.jpg',
#  'COCO_train2014_000000460872.jpg',
#  'COCO_train2014_000000368424.jpg',
#  'COCO_train2014_000000527832.jpg',
#  'COCO_train2014_000000524557.jpg',
#  'COCO_train2014_000000356869.jpg',
#  'COCO_train2014_000000359156.jpg',
#  'COCO_train2014_000000165654.jpg',
#  'COCO_train2014_000000426618.jpg',
#  'COCO_train2014_000000109654.jpg',
#  'COCO_train2014_000000419245.jpg',
#  'COCO_train2014_000000053864.jpg',
#  'COCO_train2014_000000102133.jpg',
#  'COCO_train2014_000000127122.jpg',
#  'COCO_train2014_000000105714.jpg',
#  'COCO_train2014_000000450168.jpg',
#  'COCO_train2014_000000498173.jpg',
#  'COCO_train2014_000000160848.jpg',
#  'COCO_train2014_000000022854.jpg',
#  'COCO_train2014_000000378393.jpg',
#  'COCO_train2014_000000019622.jpg',
#  'COCO_train2014_000000367788.jpg',
#  'COCO_train2014_000000335781.jpg',
#  'COCO_train2014_000000167848.jpg',
#  'COCO_train2014_000000008593.jpg',
#  'COCO_train2014_000000253890.jpg',
#  'COCO_train2014_000000229347.jpg',
#  'COCO_train2014_000000021423.jpg',
#  'COCO_train2014_000000310546.jpg',
#  'COCO_train2014_000000494812.jpg',
#  'COCO_train2014_000000253975.jpg',
#  'COCO_train2014_000000031367.jpg',
#  'COCO_train2014_000000039812.jpg',
#  'COCO_train2014_000000056572.jpg',
#  'COCO_train2014_000000083153.jpg',
#  'COCO_train2014_000000423114.jpg',
#  'COCO_train2014_000000147975.jpg',
#  'COCO_train2014_000000428117.jpg',
#  'COCO_train2014_000000421813.jpg',
#  'COCO_train2014_000000202137.jpg',
#  'COCO_train2014_000000481547.jpg',
#  'COCO_train2014_000000075190.jpg',
#  'COCO_train2014_000000170291.jpg',
#  'COCO_train2014_000000251084.jpg',
#  'COCO_train2014_000000411350.jpg',
#  'COCO_train2014_000000332261.jpg',
#  'COCO_train2014_000000393795.jpg',
#  'COCO_train2014_000000304459.jpg',
#  'COCO_train2014_000000283913.jpg',
#  'COCO_train2014_000000513888.jpg',
#  'COCO_train2014_000000504598.jpg',
#  'COCO_train2014_000000270186.jpg',
#  'COCO_train2014_000000206279.jpg',
#  'COCO_train2014_000000144488.jpg',
#  'COCO_train2014_000000351061.jpg',
#  'COCO_train2014_000000303388.jpg',
#  'COCO_train2014_000000573576.jpg',
#  'COCO_train2014_000000418198.jpg',
#  'COCO_train2014_000000308040.jpg',
#  'COCO_train2014_000000467766.jpg',
#  'COCO_train2014_000000023569.jpg',
#  'COCO_train2014_000000134937.jpg',
#  'COCO_train2014_000000480770.jpg',
#  'COCO_train2014_000000120274.jpg',
#  'COCO_train2014_000000301121.jpg',
#  'COCO_train2014_000000518015.jpg',
#  'COCO_train2014_000000185549.jpg',
#  'COCO_train2014_000000496673.jpg',
#  'COCO_train2014_000000263760.jpg',
#  'COCO_train2014_000000312379.jpg',
#  'COCO_train2014_000000441255.jpg',
#  'COCO_train2014_000000224778.jpg',
#  'COCO_train2014_000000401390.jpg',
#  'COCO_train2014_000000215081.jpg',
#  'COCO_train2014_000000404854.jpg',
#  'COCO_train2014_000000062814.jpg',
#  'COCO_train2014_000000546517.jpg',
#  'COCO_train2014_000000396536.jpg',
#  'COCO_train2014_000000204735.jpg',
#  'COCO_train2014_000000064308.jpg',
#  'COCO_train2014_000000066878.jpg',
#  'COCO_train2014_000000267435.jpg',
#  'COCO_train2014_000000318225.jpg',
#  'COCO_train2014_000000471256.jpg',
#  'COCO_train2014_000000318783.jpg',
#  'COCO_train2014_000000196584.jpg',
#  'COCO_train2014_000000194027.jpg',
#  'COCO_train2014_000000074110.jpg',
#  'COCO_train2014_000000305224.jpg',
#  'COCO_train2014_000000577738.jpg',
#  'COCO_train2014_000000399548.jpg',
#  'COCO_train2014_000000102604.jpg',
#  'COCO_train2014_000000160944.jpg',
#  'COCO_train2014_000000328371.jpg',
#  'COCO_train2014_000000345952.jpg',
#  'COCO_train2014_000000170579.jpg',
#  'COCO_train2014_000000188911.jpg',
#  'COCO_train2014_000000389718.jpg',
#  'COCO_train2014_000000440813.jpg',
#  'COCO_train2014_000000181042.jpg',
#  'COCO_train2014_000000500525.jpg',
#  'COCO_train2014_000000053147.jpg',
#  'COCO_train2014_000000311220.jpg',
#  'COCO_train2014_000000338515.jpg',
#  'COCO_train2014_000000467203.jpg',
#  'COCO_train2014_000000121083.jpg',
#  'COCO_train2014_000000542814.jpg',
#  'COCO_train2014_000000051390.jpg',
#  'COCO_train2014_000000329751.jpg',
#  'COCO_train2014_000000214848.jpg',
#  'COCO_train2014_000000088802.jpg',
#  'COCO_train2014_000000575837.jpg',
#  'COCO_train2014_000000567633.jpg',
#  'COCO_train2014_000000456376.jpg',
#  'COCO_train2014_000000019836.jpg',
#  'COCO_train2014_000000259393.jpg',
#  'COCO_train2014_000000562382.jpg',
#  'COCO_train2014_000000316725.jpg',
#  'COCO_train2014_000000219099.jpg',
#  'COCO_train2014_000000396572.jpg',
#  'COCO_train2014_000000439402.jpg',
#  'COCO_train2014_000000138234.jpg',
#  'COCO_train2014_000000222015.jpg',
#  'COCO_train2014_000000482371.jpg',
#  'COCO_train2014_000000527752.jpg',
#  'COCO_train2014_000000085802.jpg',
#  'COCO_train2014_000000157119.jpg',
#  'COCO_train2014_000000220449.jpg',
#  'COCO_train2014_000000090712.jpg',
#  'COCO_train2014_000000243846.jpg',
#  'COCO_train2014_000000357865.jpg',
#  'COCO_train2014_000000264353.jpg',
#  'COCO_train2014_000000189949.jpg',
#  'COCO_train2014_000000329707.jpg',
#  'COCO_train2014_000000481039.jpg',
#  'COCO_train2014_000000572791.jpg',
#  'COCO_train2014_000000071664.jpg',
#  'COCO_train2014_000000016827.jpg',
#  'COCO_train2014_000000170765.jpg',
#  'COCO_train2014_000000238735.jpg',
#  'COCO_train2014_000000238850.jpg',
#  'COCO_train2014_000000032699.jpg',
#  'COCO_train2014_000000128405.jpg',
#  'COCO_train2014_000000496109.jpg',
#  'COCO_train2014_000000190732.jpg',
#  'COCO_train2014_000000101426.jpg',
#  'COCO_train2014_000000141386.jpg',
#  'COCO_train2014_000000219762.jpg',
#  'COCO_train2014_000000043388.jpg',
#  'COCO_train2014_000000391492.jpg',
#  'COCO_train2014_000000287639.jpg',
#  'COCO_train2014_000000355863.jpg',
#  'COCO_train2014_000000484353.jpg',
#  'COCO_train2014_000000268068.jpg',
#  'COCO_train2014_000000041713.jpg',
#  'COCO_train2014_000000220408.jpg',
#  'COCO_train2014_000000457805.jpg',
#  'COCO_train2014_000000389304.jpg',
#  'COCO_train2014_000000017356.jpg',
#  'COCO_train2014_000000055496.jpg',
#  'COCO_train2014_000000157748.jpg',
#  'COCO_train2014_000000437944.jpg',
#  'COCO_train2014_000000124764.jpg',
#  'COCO_train2014_000000034882.jpg',
#  'COCO_train2014_000000428214.jpg',
#  'COCO_train2014_000000415475.jpg',
#  'COCO_train2014_000000294133.jpg',
#  'COCO_train2014_000000316561.jpg',
#  'COCO_train2014_000000556888.jpg',
#  'COCO_train2014_000000566201.jpg',
#  'COCO_train2014_000000211234.jpg',
#  'COCO_train2014_000000253656.jpg',
#  'COCO_train2014_000000001307.jpg',
#  'COCO_train2014_000000304694.jpg',
#  'COCO_train2014_000000042089.jpg',
#  'COCO_train2014_000000186246.jpg',
#  'COCO_train2014_000000275530.jpg',
#  'COCO_train2014_000000300189.jpg',
#  'COCO_train2014_000000313570.jpg',
#  'COCO_train2014_000000200764.jpg',
#  'COCO_train2014_000000567438.jpg',
#  'COCO_train2014_000000439336.jpg',
#  'COCO_train2014_000000341942.jpg',
#  'COCO_train2014_000000320744.jpg',
#  'COCO_train2014_000000096582.jpg',
#  'COCO_train2014_000000317428.jpg',
#  'COCO_train2014_000000368309.jpg',
#  'COCO_train2014_000000242194.jpg',
#  'COCO_train2014_000000505402.jpg',
#  'COCO_train2014_000000217226.jpg',
#  'COCO_train2014_000000172680.jpg',
#  'COCO_train2014_000000433217.jpg',
#  'COCO_train2014_000000333664.jpg',
#  'COCO_train2014_000000329952.jpg',
#  'COCO_train2014_000000072702.jpg',
#  'COCO_train2014_000000375857.jpg',
#  'COCO_train2014_000000251860.jpg',
#  'COCO_train2014_000000217448.jpg',
#  'COCO_train2014_000000443349.jpg',
#  'COCO_train2014_000000420713.jpg',
#  'COCO_train2014_000000246041.jpg',
#  'COCO_train2014_000000374976.jpg',
#  'COCO_train2014_000000204170.jpg',
#  'COCO_train2014_000000567106.jpg',
#  'COCO_train2014_000000577762.jpg',
#  'COCO_train2014_000000366146.jpg',
#  'COCO_train2014_000000000955.jpg',
#  'COCO_train2014_000000374994.jpg',
#  'COCO_train2014_000000168440.jpg',
#  'COCO_train2014_000000096475.jpg',
#  'COCO_train2014_000000550934.jpg',
#  'COCO_train2014_000000128346.jpg',
#  'COCO_train2014_000000298512.jpg',
#  'COCO_train2014_000000104564.jpg',
#  'COCO_train2014_000000534941.jpg',
#  'COCO_train2014_000000283757.jpg',
#  'COCO_train2014_000000251690.jpg',
#  'COCO_train2014_000000275977.jpg',
#  'COCO_train2014_000000301998.jpg',
#  'COCO_train2014_000000580753.jpg',
#  'COCO_train2014_000000525467.jpg',
#  'COCO_train2014_000000159965.jpg',
#  'COCO_train2014_000000133731.jpg',
#  'COCO_train2014_000000483458.jpg',
#  'COCO_train2014_000000579604.jpg',
#  'COCO_train2014_000000362365.jpg',
#  'COCO_train2014_000000160823.jpg',
#  'COCO_train2014_000000439117.jpg',
#  'COCO_train2014_000000092032.jpg',
#  'COCO_train2014_000000564237.jpg',
#  'COCO_train2014_000000191828.jpg',
#  'COCO_train2014_000000246312.jpg',
#  'COCO_train2014_000000389770.jpg',
#  'COCO_train2014_000000025854.jpg',
#  'COCO_train2014_000000380100.jpg',
#  'COCO_train2014_000000343608.jpg',
#  'COCO_train2014_000000180569.jpg',
#  'COCO_train2014_000000022429.jpg',
#  'COCO_train2014_000000305564.jpg',
#  'COCO_train2014_000000362758.jpg',
#  'COCO_train2014_000000491225.jpg',
#  'COCO_train2014_000000087501.jpg',
#  'COCO_train2014_000000157377.jpg',
#  'COCO_train2014_000000578718.jpg',
#  'COCO_train2014_000000385903.jpg',
#  'COCO_train2014_000000398632.jpg',
#  'COCO_train2014_000000368845.jpg',
#  'COCO_train2014_000000575675.jpg',
#  'COCO_train2014_000000525625.jpg',
#  'COCO_train2014_000000497900.jpg',
#  'COCO_train2014_000000294954.jpg',
#  'COCO_train2014_000000292421.jpg',
#  'COCO_train2014_000000004956.jpg',
#  'COCO_train2014_000000118207.jpg',
#  'COCO_train2014_000000471357.jpg',
#  'COCO_train2014_000000372660.jpg',
#  'COCO_train2014_000000117275.jpg',
#  'COCO_train2014_000000110447.jpg',
#  'COCO_train2014_000000336395.jpg',
#  'COCO_train2014_000000115117.jpg',
#  'COCO_train2014_000000579729.jpg',
#  'COCO_train2014_000000259186.jpg',
#  'COCO_train2014_000000343057.jpg',
#  'COCO_train2014_000000107188.jpg',
#  'COCO_train2014_000000477031.jpg',
#  'COCO_train2014_000000268472.jpg',
#  'COCO_train2014_000000331457.jpg',
#  'COCO_train2014_000000166021.jpg',
#  'COCO_train2014_000000438462.jpg',
#  'COCO_train2014_000000414113.jpg',
#  'COCO_train2014_000000014970.jpg',
#  'COCO_train2014_000000407959.jpg',
#  'COCO_train2014_000000256655.jpg',
#  'COCO_train2014_000000574360.jpg',
#  'COCO_train2014_000000316759.jpg',
#  'COCO_train2014_000000320144.jpg',
#  'COCO_train2014_000000079680.jpg',
#  'COCO_train2014_000000249306.jpg',
#  'COCO_train2014_000000500904.jpg',
#  'COCO_train2014_000000518844.jpg',
#  'COCO_train2014_000000206083.jpg',
#  'COCO_train2014_000000513918.jpg',
#  'COCO_train2014_000000027591.jpg',
#  'COCO_train2014_000000564235.jpg',
#  'COCO_train2014_000000420151.jpg',
#  'COCO_train2014_000000518764.jpg',
#  'COCO_train2014_000000473337.jpg',
#  'COCO_train2014_000000320563.jpg',
#  'COCO_train2014_000000048408.jpg',
#  'COCO_train2014_000000418723.jpg',
#  'COCO_train2014_000000455776.jpg',
#  'COCO_train2014_000000139344.jpg',
#  'COCO_train2014_000000508516.jpg',
#  'COCO_train2014_000000048478.jpg',
#  'COCO_train2014_000000044446.jpg',
#  'COCO_train2014_000000121852.jpg',
#  'COCO_train2014_000000352564.jpg',
#  'COCO_train2014_000000540479.jpg',
#  'COCO_train2014_000000092714.jpg',
#  'COCO_train2014_000000059442.jpg',
#  'COCO_train2014_000000168194.jpg',
#  'COCO_train2014_000000359414.jpg',
#  'COCO_train2014_000000207880.jpg',
#  'COCO_train2014_000000197950.jpg',
#  'COCO_train2014_000000185358.jpg',
#  'COCO_train2014_000000057166.jpg',
#  'COCO_train2014_000000294933.jpg',
#  'COCO_train2014_000000226460.jpg',
#  'COCO_train2014_000000481391.jpg',
#  'COCO_train2014_000000243136.jpg',
#  'COCO_train2014_000000180613.jpg',
#  'COCO_train2014_000000439373.jpg',
#  'COCO_train2014_000000118581.jpg',
#  'COCO_train2014_000000027599.jpg',
#  'COCO_train2014_000000176506.jpg',
#  'COCO_train2014_000000533826.jpg',
#  'COCO_train2014_000000292912.jpg',
#  'COCO_train2014_000000010161.jpg',
#  'COCO_train2014_000000072531.jpg',
#  'COCO_train2014_000000509682.jpg',
#  'COCO_train2014_000000256474.jpg',
#  'COCO_train2014_000000322024.jpg',
#  'COCO_train2014_000000231675.jpg',
#  'COCO_train2014_000000517070.jpg',
#  'COCO_train2014_000000277331.jpg',
#  'COCO_train2014_000000009744.jpg',
#  'COCO_train2014_000000134294.jpg',
#  'COCO_train2014_000000027723.jpg',
#  'COCO_train2014_000000440783.jpg',
#  'COCO_train2014_000000400408.jpg',
#  'COCO_train2014_000000275939.jpg',
#  'COCO_train2014_000000252122.jpg',
#  'COCO_train2014_000000273783.jpg',
#  'COCO_train2014_000000194842.jpg',
#  'COCO_train2014_000000109084.jpg',
#  'COCO_train2014_000000118777.jpg',
#  'COCO_train2014_000000059641.jpg',
#  'COCO_train2014_000000562602.jpg',
#  'COCO_train2014_000000229596.jpg',
#  'COCO_train2014_000000178577.jpg',
#  'COCO_train2014_000000321753.jpg',
#  'COCO_train2014_000000563076.jpg',
#  'COCO_train2014_000000401838.jpg',
#  'COCO_train2014_000000352401.jpg',
#  'COCO_train2014_000000338230.jpg',
#  'COCO_train2014_000000547859.jpg',
#  'COCO_train2014_000000281161.jpg',
#  'COCO_train2014_000000161673.jpg',
#  'COCO_train2014_000000204837.jpg',
#  'COCO_train2014_000000063691.jpg',
#  'COCO_train2014_000000261630.jpg',
#  'COCO_train2014_000000264473.jpg',
#  'COCO_train2014_000000427251.jpg',
#  'COCO_train2014_000000161515.jpg',
#  'COCO_train2014_000000363656.jpg',
#  'COCO_train2014_000000443049.jpg',
#  'COCO_train2014_000000157397.jpg',
#  'COCO_train2014_000000219523.jpg',
#  'COCO_train2014_000000110004.jpg',
#  'COCO_train2014_000000376128.jpg',
#  'COCO_train2014_000000058497.jpg',
#  'COCO_train2014_000000348451.jpg',
#  'COCO_train2014_000000313553.jpg',
#  'COCO_train2014_000000399191.jpg',
#  'COCO_train2014_000000434239.jpg',
#  'COCO_train2014_000000041781.jpg',
#  ...]

# %%
data_pt['embeddings']
# Out:
# tensor([[ 0.0044,  0.0386,  0.0086,  ...,  0.1112, -0.0252,  0.0167],
#         [-0.0074,  0.0594,  0.0263,  ...,  0.0550,  0.0061, -0.0366],
#         [ 0.0126,  0.0143,  0.0014,  ...,  0.0509,  0.0260,  0.0367],
#         ...,
#         [-0.0117,  0.0183, -0.0192,  ...,  0.1000,  0.0164, -0.0103],
#         [-0.0308, -0.0024,  0.0178,  ...,  0.0631,  0.0074,  0.0170],
#         [ 0.0118,  0.0193, -0.0262,  ...,  0.0361, -0.0006,  0.0091]])

# %%
data_pt['filenames']

# extract out the image ids from the filenames
def get_image_id_from_filename(filename: str) -> int:
    """Extracts the image ID from a COCO filename.
    E.g., 'COCO_train2014_000000123456.jpg' -> 123456
    """
    base_name = filename.split('_')[-1]  # '000000123456.jpg'
    image_id_str = base_name.split('.')[0]  # '000000123456'
    return int(image_id_str)

get_image_id_from_filename(data_pt['filenames'][0])
# Out:
# 263229

# %%
# Create a mapping from image_id to all its captions
from collections import defaultdict

image_to_captions = defaultdict(list)
for ann in data['annotations']:
    image_to_captions[ann['image_id']].append({
        'caption_id': ann['id'],
        'caption': ann['caption']
    })

print(f"Total unique images with captions: {len(image_to_captions)}")
print(f"Sample captions for first image: {list(image_to_captions.values())[0]}")
# Out:
# Total unique images with captions: 82783
# Sample captions for first image: [{'caption_id': 48, 'caption': 'A very clean and well decorated empty bathroom'}, {'caption_id': 126, 'caption': 'A blue and white bathroom with butterfly themed wall tiles.'}, {'caption_id': 219, 'caption': 'A bathroom with a border of butterflies and blue paint on the walls above it.'}, {'caption_id': 255, 'caption': 'An angled view of a beautifully decorated bathroom.'}, {'caption_id': 3555, 'caption': 'A clock that blends in with the wall hangs in a bathroom. '}]

# %%
# Now we need caption embeddings - load or compute them
# Assuming you have a model to generate embeddings for captions
from transformers import GPT2Tokenizer, GPT2Model

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2Model.from_pretrained('gpt2')
model.eval()

def get_caption_embedding(caption: str) -> torch.Tensor:
    """Generate embedding for a caption using GPT2."""
    inputs = tokenizer(caption, return_tensors='pt', padding=True, truncation=True)
    with torch.no_grad():
        outputs = model(**inputs)
        # Use the mean of the last hidden state as the embedding
        embedding = outputs.last_hidden_state.mean(dim=1).squeeze()
    return embedding

# %%
# Process all images and their captions
processed_data = []

for filename in data_pt['filenames']:
    image_id = get_image_id_from_filename(filename)
    
    # Get all captions for this image
    captions_info = image_to_captions.get(image_id, [])
    
    if not captions_info:
        continue
    
    # Generate embeddings for each caption
    caption_embeddings = []
    for cap_info in captions_info:
        embedding = get_caption_embedding(cap_info['caption'])
        caption_embeddings.append({
            'caption_id': cap_info['caption_id'],
            'embedding': embedding
        })
    
    # Structure as requested
    processed_data.append({
        'filename': image_id,
        'caption_embeddings': caption_embeddings
    })

print(f"Processed {len(processed_data)} images")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 16
#      14 caption_embeddings = []
#      15 for cap_info in captions_info:
# ---> 16     embedding = get_caption_embedding(cap_info['caption'])
#      17     caption_embeddings.append({
#      18         'caption_id': cap_info['caption_id'],
#      19         'embedding': embedding
#      20     })
#      22 # Structure as requested
#
# Cell In[35], line 11, in get_caption_embedding(caption)
#       9 def get_caption_embedding(caption: str) -> torch.Tensor:
#      10     """Generate embedding for a caption using GPT2."""
# ---> 11     inputs = tokenizer(caption, return_tensors='pt', padding=True, truncation=True)
#      12     with torch.no_grad():
#      13         outputs = model(**inputs)
#
# File /mnt/c/Users/hoxia/Documents/NLDeeznuts/gpt2-image-captioning/.venv/lib/python3.13/site-packages/transformers/tokenization_utils_base.py:3073, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3071     if not self._in_target_context_manager:
#    3072         self._switch_to_input_mode()
# -> 3073     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    3074 if text_target is not None:
#    3075     self._switch_to_target_mode()
#
# File /mnt/c/Users/hoxia/Documents/NLDeeznuts/gpt2-image-captioning/.venv/lib/python3.13/site-packages/transformers/tokenization_utils_base.py:3183, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3161     return self.batch_encode_plus(
#    3162         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3163         add_special_tokens=add_special_tokens,
#    (...)   3180         **kwargs,
#    3181     )
#    3182 else:
# -> 3183     return self.encode_plus(
#    3184         text=text,
#    3185         text_pair=text_pair,
#    3186         add_special_tokens=add_special_tokens,
#    3187         padding=padding,
#    3188         truncation=truncation,
#    3189         max_length=max_length,
#    3190         stride=stride,
#    3191         is_split_into_words=is_split_into_words,
#    3192         pad_to_multiple_of=pad_to_multiple_of,
#    3193         padding_side=padding_side,
#    3194         return_tensors=return_tensors,
#    3195         return_token_type_ids=return_token_type_ids,
#    3196         return_attention_mask=return_attention_mask,
#    3197         return_overflowing_tokens=return_overflowing_tokens,
#    3198         return_special_tokens_mask=return_special_tokens_mask,
#    3199         return_offsets_mapping=return_offsets_mapping,
#    3200         return_length=return_length,
#    3201         verbose=verbose,
#    3202         split_special_tokens=split_special_tokens,
#    3203         **kwargs,
#    3204     )
#
# File /mnt/c/Users/hoxia/Documents/NLDeeznuts/gpt2-image-captioning/.venv/lib/python3.13/site-packages/transformers/tokenization_utils_base.py:3249, in PreTrainedTokenizerBase.encode_plus(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3206 @add_end_docstrings(ENCODE_KWARGS_DOCSTRING, ENCODE_PLUS_ADDITIONAL_KWARGS_DOCSTRING)
#    3207 def encode_plus(
#    3208     self,
#    (...)   3227     **kwargs,
#    3228 ) -> BatchEncoding:
#    3229     """
#    3230     Tokenize and prepare for the model a sequence or a pair of sequences.
#    3231
#    (...)   3246             method).
#    3247     """
# -> 3249     padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3250         padding=padding,
#    3251         truncation=truncation,
#    3252         max_length=max_length,
#    3253         pad_to_multiple_of=pad_to_multiple_of,
#    3254         verbose=verbose,
#    3255         **kwargs,
#    3256     )
#    3258     return self._encode_plus(
#    3259         text=text,
#    3260         text_pair=text_pair,
#    (...)   3278         **kwargs,
#    3279     )
#
# File /mnt/c/Users/hoxia/Documents/NLDeeznuts/gpt2-image-captioning/.venv/lib/python3.13/site-packages/transformers/tokenization_utils_base.py:2969, in PreTrainedTokenizerBase._get_padding_truncation_strategies(self, padding, truncation, max_length, pad_to_multiple_of, verbose, **kwargs)
#    2967 # Test if we have a padding token
#    2968 if padding_strategy != PaddingStrategy.DO_NOT_PAD and (self.pad_token is None or self.pad_token_id < 0):
# -> 2969     raise ValueError(
#    2970         "Asking to pad but the tokenizer does not have a padding token. "
#    2971         "Please select a token to use as `pad_token` `(tokenizer.pad_token = tokenizer.eos_token e.g.)` "
#    2972         "or add a new pad token via `tokenizer.add_special_tokens({'pad_token': '[PAD]'})`."
#    2973     )
#    2975 # Check that we will truncate to a multiple of pad_to_multiple_of if both are provided
#    2976 if (
#    2977     truncation_strategy != TruncationStrategy.DO_NOT_TRUNCATE
#    2978     and padding_strategy != PaddingStrategy.DO_NOT_PAD
#    (...)   2981     and (max_length % pad_to_multiple_of != 0)
#    2982 ):
#
# ValueError: Asking to pad but the tokenizer does not have a padding token. Please select a token to use as `pad_token` `(tokenizer.pad_token = tokenizer.eos_token e.g.)` or add a new pad token via `tokenizer.add_special_tokens({'pad_token': '[PAD]'})`.

# %%
# Save the processed data
output_path = "/mnt/c/Users/hoxia/Documents/NLDeeznuts/gpt2-image-captioning/data/data/coco/embeddings/caption_embeddings_structured.pt"
torch.save(processed_data, output_path)
print(f"Saved to {output_path}")

# Verify the structure
sample = processed_data[0]
print(f"\nSample structure:")
print(f"Filename (image_id): {sample['filename']}")
print(f"Number of captions: {len(sample['caption_embeddings'])}")
print(f"First caption_id: {sample['caption_embeddings'][0]['caption_id']}")
print(f"Embedding shape: {sample['caption_embeddings'][0]['embedding'].shape}")

# %%
run_indexing_pipeline(db_directory="/mnt/c/Users/hoxia/Documents/NLDeeznuts/gpt2-image-captioning/src/database/objectbox_db",
                      image_embedding_file_path="/mnt/c/Users/hoxia/Documents/NLDeeznuts/gpt2-image-captioning/data/data/coco/embeddings/train_val_clip_embeddings.pt",
                      caption_embedding_file_path="/mnt/c/Users/hoxia/Documents/NLDeeznuts/gpt2-image-captioning/data/data/coco/embeddings/caption_embeddings_structured.pt"
                      )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[39], line 8
#       5 project_root = Path("/mnt/c/Users/hoxia/Documents/NLDeeznuts/gpt2-image-captioning")
#       6 sys.path.insert(0, str(project_root))
# ----> 8 from src.database.indexing import run_indexing_pipeline
#      10 run_indexing_pipeline(db_directory="/mnt/c/Users/hoxia/Documents/NLDeeznuts/gpt2-image-captioning/src/database/objectbox_db",
#      11                       image_embedding_file_path="/mnt/c/Users/hoxia/Documents/NLDeeznuts/gpt2-image-captioning/data/data/coco/embeddings/train_val_clip_embeddings.pt",
#      12                       caption_embedding_file_path="/mnt/c/Users/hoxia/Documents/NLDeeznuts/gpt2-image-captioning/data/data/coco/embeddings/caption_embeddings_structured.pt")
#
# File /mnt/c/Users/hoxia/Documents/NLDeeznuts/gpt2-image-captioning/src/database/indexing.py:10
#       7 from tqdm import tqdm
#       8 import torch
# ---> 10 from src.database.entities import Image
#      11 from src.database.image_store import create_objectbox_store, add_images_to_store
#      12 from src.embeddings.clip import load_clip_model
#
# File /mnt/c/Users/hoxia/Documents/NLDeeznuts/gpt2-image-captioning/src/database/entities.py:16
#       1 """
#       2 src/entities.py
#       3
#       4 Defines ObjectBox entities for storing documents and chunks with vector embeddings.
#       5 """
#       7 from objectbox import (
#       8     Entity,
#       9     Float32Vector,
#    (...)     13     VectorDistanceType,
#      14 )
# ---> 16 from database.config import (
#      17     IMAGE_EMBEDDING_DIMENSIONS,
#      18     CAPTION_EMBEDDING_DIMENSIONS,
#      19     INDEXING_SEARCH_COUNT,
#      20     NEIGHBORS_PER_NODE,
#      21     NORMALIZE_EMBEDDINGS,
#      22 )
#      24 @Entity()
#      25 class Image:
#      26     """
#      27     Represents an image in the dataset with its text and image embedding vector.
#      28     """
#
# ModuleNotFoundError: No module named 'database'
